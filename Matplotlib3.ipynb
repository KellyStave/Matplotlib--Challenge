# %%
#dependencies and set-up
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
#data files and read results
mouse_path = r"C:\Users\stave\OneDrive\Desktop\Bootcamp\week 5\Challenge\Mouse_metadata.csv"
study_path = r"C:\Users\stave\OneDrive\Desktop\Bootcamp\week 5\Challenge\Study_results.csv"
mouse = pd.read_csv(mouse_path, encoding= 'utf-8')
study = pd.read_csv(study_path, encoding= 'utf-8')
mouse
study
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0        b128          0           45.000000                 0
# 1        f932          0           45.000000                 0
# 2        g107          0           45.000000                 0
# 3        a457          0           45.000000                 0
# 4        c819          0           45.000000                 0
# ...       ...        ...                 ...               ...
# 1888     r944         45           41.581521                 2
# 1889     u364         45           31.023923                 3
# 1890     p438         45           61.433892                 1
# 1891     x773         45           58.634971                 4
# 1892     b879         45           72.555239                 2
#
# [1893 rows x 4 columns]

# %%
#merge data files
merge = pd.merge(mouse, study, how="left", on=["Mouse ID", "Mouse ID"])
merge
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1893 rows x 8 columns]

# %%
#count number of unique mice id
mice_id = merge["Mouse ID"].nunique()
mice_id
# Out:
# 249

# %%
#find duplicate mice id
duplicate = merge[merge.duplicated(['Mouse ID', 'Timepoint'])]
duplicate
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
#create dataframe without duplicate mice information
duplicate2 = merge.drop_duplicates(['Mouse ID', 'Timepoint'], keep= False)
duplicate2
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# 2              35.014271                 1
# 3              34.223992                 1
# 4              32.997729                 1
# ...                  ...               ...
# 1888           63.145652                 2
# 1889           65.841013                 3
# 1890           69.176246                 4
# 1891           70.314904                 4
# 1892           73.867845                 4
#
# [1883 rows x 8 columns]

# %%
#calculate unique mouse count
mice_id2 = duplicate2["Mouse ID"].nunique()
mice_id2
# Out:
# 249

# %%
#calculate mean of tumor volume based on drug regimen
mean = duplicate2.groupby(['Drug Regimen']).mean()['Tumor Volume (mm3)']
mean
# Out:
# Drug Regimen
# Capomulin    40.675741
# Ceftamin     52.591172
# Infubinol    52.884795
# Ketapril     55.235638
# Naftisol     54.331565
# Placebo      54.033581
# Propriva     52.458254
# Ramicane     40.216745
# Stelasyn     54.233149
# Zoniferol    53.236507
# Name: Tumor Volume (mm3), dtype: float64

# %%
#calculate median of tumor volume based on drug regimen
median = duplicate2.groupby(['Drug Regimen']).median()['Tumor Volume (mm3)']
median
# Out:
# Drug Regimen
# Capomulin    41.557809
# Ceftamin     51.776157
# Infubinol    51.820584
# Ketapril     53.698743
# Naftisol     52.509285
# Placebo      52.288934
# Propriva     50.854632
# Ramicane     40.673236
# Stelasyn     52.431737
# Zoniferol    51.818479
# Name: Tumor Volume (mm3), dtype: float64

# %%
#calculate variance of tumor volume based on drug regimen
variance = duplicate2.groupby(['Drug Regimen']).var()['Tumor Volume (mm3)']
variance
# Out:
# Drug Regimen
# Capomulin    24.947764
# Ceftamin     39.290177
# Infubinol    43.128684
# Ketapril     68.553577
# Naftisol     66.173479
# Placebo      61.168083
# Propriva     44.053659
# Ramicane     23.486704
# Stelasyn     59.450562
# Zoniferol    48.533355
# Name: Tumor Volume (mm3), dtype: float64

# %%
#calculate standard deviation of tumor volume based on drug regimen
standard_deviation = duplicate2.groupby(['Drug Regimen']).std()['Tumor Volume (mm3)']
standard_deviation
# Out:
# Drug Regimen
# Capomulin    4.994774
# Ceftamin     6.268188
# Infubinol    6.567243
# Ketapril     8.279709
# Naftisol     8.134708
# Placebo      7.821003
# Propriva     6.637293
# Ramicane     4.846308
# Stelasyn     7.710419
# Zoniferol    6.966589
# Name: Tumor Volume (mm3), dtype: float64

# %%
#calculate standard error of tumor volume based on drug regimen
standard_error = duplicate2.groupby(['Drug Regimen']).sem()['Tumor Volume (mm3)']
standard_error
# Out:
# Drug Regimen
# Capomulin    0.329346
# Ceftamin     0.469821
# Infubinol    0.492236
# Ketapril     0.603860
# Naftisol     0.596466
# Placebo      0.581331
# Propriva     0.540135
# Ramicane     0.320955
# Stelasyn     0.573111
# Zoniferol    0.516398
# Name: Tumor Volume (mm3), dtype: float64

# %%
#create dataframe for calculations of tumor volume based on drug regimen
summary = pd.DataFrame({
    'Mean Tumor Volume': mean, 
    'Median Tumor Volume': median, 
    'Tumor Volume Variance': variance, 
    'Tumor Volume Std. Dev': standard_deviation, 
    'Tumor Volume Std. Err': standard_error
})
summary
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.458254            50.854632              44.053659
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev  Tumor Volume Std. Err
# Drug Regimen
# Capomulin                  4.994774               0.329346
# Ceftamin                   6.268188               0.469821
# Infubinol                  6.567243               0.492236
# Ketapril                   8.279709               0.603860
# Naftisol                   8.134708               0.596466
# Placebo                    7.821003               0.581331
# Propriva                   6.637293               0.540135
# Ramicane                   4.846308               0.320955
# Stelasyn                   7.710419               0.573111
# Zoniferol                  6.966589               0.516398

# %%
#calculate values using aggregate
aggregate = duplicate2.groupby(['Drug Regimen']).agg(['mean', 'median', 'var', 'std', 'sem'])['Tumor Volume (mm3)']
aggregate
# Out:
# C:\Users\stave\AppData\Local\Temp\ipykernel_20736\1788089438.py:2: FutureWarning: ['Mouse ID', 'Sex'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   aggregate = duplicate2.groupby(['Drug Regimen']).agg(['mean', 'median', 'var', 'std', 'sem'])['Tumor Volume (mm3)']
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.458254  50.854632  44.053659  6.637293  0.540135
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
#Create bar chart with pandas for drug regimen vs timepoint
drug_groups = duplicate2.groupby('Drug Regimen')

timepoint = drug_groups['Timepoint'].count()

drug_vs_time = timepoint.plot(kind="bar", title="Drug Regimen vs. Timepoint")
drug_vs_time.set_xlabel("Drug Regimen")
drug_vs_time.set_ylabel("Number of Mice Tested")

plt.show()

# %%
#Create bar chart with pyplot for drug regimen vs timepoint
plt.bar(timepoint.index, timepoint.values)
plt.xlabel('Drug Regimen')
plt.ylabel('Number of Mice Tested')
plt.xticks(rotation = 90)
plt.show()

# %%
#Create pie chart with pandas for mouse gender
gender = duplicate2.groupby(['Sex']).count()
gender_pie = duplicate2.groupby(['Sex']).count().plot(kind='pie', y = 'Mouse ID', autopct='%1.0f%%')
gender_pie
# Out:
# <AxesSubplot:ylabel='Mouse ID'>

# %%
#Create pie chart with pyplot for mouse gender
gender = duplicate2.groupby(['Sex']).count()
plt.pie(gender["Mouse ID"], labels = gender.index, autopct='%1.0f%%')
plt.show()

# %%
#calculate last timepoint for each mouse
max_time = duplicate2.groupby(["Mouse ID"])['Timepoint'].max()
max_time = max_time.reset_index()

# %%
#merge last timepoint with original dataframe 
merge2 = max_time.merge(duplicate2,on=['Mouse ID','Timepoint'],how="left")
merge2
# Out:
#     Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0       a203         45    Infubinol  Female          20          23
# 1       a251         45    Infubinol  Female          21          25
# 2       a262         45      Placebo  Female          17          29
# 3       a275         45     Ceftamin  Female          20          28
# 4       a366         30     Stelasyn  Female          16          29
# ..       ...        ...          ...     ...         ...         ...
# 244     z435         10     Propriva  Female          12          26
# 245     z578         45     Ramicane    Male          11          16
# 246     z581         45    Infubinol  Female          24          25
# 247     z795         45     Naftisol  Female          13          29
# 248     z969         45     Naftisol    Male           9          30
#
#      Tumor Volume (mm3)  Metastatic Sites
# 0             67.973419                 2
# 1             65.525743                 1
# 2             70.717621                 4
# 3             62.999356                 3
# 4             63.440686                 1
# ..                  ...               ...
# 244           48.710661                 0
# 245           30.638696                 0
# 246           62.754451                 3
# 247           65.741070                 3
# 248           73.867845                 4
#
# [249 rows x 8 columns]

# %%
final_volume = merge2.groupby(['Drug Regimen', 'Mouse ID']).sum()[['Tumor Volume (mm3)']]
final_volume
# Out:
#                        Tumor Volume (mm3)
# Drug Regimen Mouse ID
# Capomulin    b128               38.982878
#              b742               38.939633
#              f966               30.485985
#              g288               37.074024
#              g316               40.159220
# ...                                   ...
# Zoniferol    q633               70.827796
#              s337               62.109651
#              w140               47.717952
#              w575               68.401286
#              x613               48.077646
#
# [249 rows x 1 columns]

# %%
treatment = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
tumor_volume = []
for x in treatment:
    tumor_volume.append(merge2.loc[(merge2['Drug Regimen']==x), 'Tumor Volume (mm3)'])

# %%
fig1, ax1 = plt.subplots()
ax1.set_ylabel("Tumor Volume (mm3)")
ax1.boxplot(tumor_volume, labels = treatment)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
outlierListUpper = []
outlierListLower = []
outlierListDrugLower =[]
outlierListDrugUpper = []
for x in treatment: 
    drugtumor = merge2.loc[(merge2['Drug Regimen']==x), 'Tumor Volume (mm3)']
    quartiles = drugtumor.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print("For " + x + " the Upper and Lower quartiles are: " + str(upperq) + ", " + str(lowerq) + 
          " and the IQR, upper and lower bounds are " + str(iqr) + ", " + str(upper_bound) + ", " + str(lower_bound))
    for y in drugtumor:
        if y < lower_bound:
            outlierListLower.append(y)
            outlierListDrugLower.append(x)
        if y > upper_bound:
            outlierListUpper.append(y)
            outlierListDrugUpper.append(x)

print("The outlier is: " + str(outlierListLower) + " in drug regimen: " + str(outlierListDrugLower))
# Out:
# For Capomulin the Upper and Lower quartiles are: 40.1592203, 32.37735684 and the IQR, upper and lower bounds are 7.781863460000004, 51.83201549, 20.70456164999999
# For Ramicane the Upper and Lower quartiles are: 40.65900627, 31.56046955 and the IQR, upper and lower bounds are 9.098536719999998, 54.30681135, 17.912664470000003
# For Infubinol the Upper and Lower quartiles are: 65.52574285, 54.04860769 and the IQR, upper and lower bounds are 11.477135160000003, 82.74144559000001, 36.83290494999999
# For Ceftamin the Upper and Lower quartiles are: 64.29983003, 48.72207785 and the IQR, upper and lower bounds are 15.577752179999997, 87.66645829999999, 25.355449580000002
# The outlier is: [36.3213458] in drug regimen: ['Infubinol']

# %%
capomulin = merge2.loc[merge2["Drug Regimen"] == "Capomulin"]

# %%
averageCap = duplicate2.loc[duplicate2["Drug Regimen"] == "Capomulin"]
averageCap = averageCap.groupby(["Mouse ID"]).mean()

# %%
x_axis = capomulin['Weight (g)']
y_axis = averageCap['Tumor Volume (mm3)']
plt.scatter(x_axis, y_axis)
plt.xlabel("Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_axis, y_axis)
regress_values = x_axis * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_axis, regress_values, "r-")
plt.show()

# %%
correlation = st.pearsonr(x_axis,y_axis)
round(correlation[0], 2)
# Out:
# 0.84

# %%
x_axis = duplicate2.loc[duplicate2["Mouse ID"]== "l509","Timepoint"]
y_axis = duplicate2.loc[duplicate2["Mouse ID"]== "l509","Tumor Volume (mm3)"]
#x_axis = i509['Timepoint']
#y_axis = i509['Tumor Volume (mm3)']
plt.plot(x_axis, y_axis)
plt.xlabel("Timepoint (Days)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Capomulin treatment of mouse l509")
plt.show()
